# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../tfx_pipeline/artifacts/training_pipeline/Trainer/model_run/6/emissions.csv")
plt.bar(["CPU", "RAM"], [df["cpu_energy"][0], df["ram_energy"][0]])
plt.ylabel("Energy (kWh)")
plt.title("Energy Breakdown per Component")
plt.show()
